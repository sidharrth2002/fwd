# %%
import tweepy
import json
import spacy
import preprocessor as p

# %%
credentials = json.load(open('credentials.json'))
consumer_key = credentials['consumer_key']
consumer_secret = credentials['consumer_secret']
access_token = credentials['access_token']
access_token_secret = credentials['access_token_secret']
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

def search_twitter(query):
    tweets = tweepy.Cursor(api.search_tweets, q=query, tweet_mode='extended').items(1000)
    return tweets

# %%
insurance_results = search_twitter('insurance')

# %%
results_json = []
for result in insurance_results:
    results_json.append(result._json)

# %%
# write to file
with open('insurance_tweets.json', 'w') as f:
    json.dump(results_json, f)

# %%
# convert to dataframe
import pandas as pd

df = pd.read_json('insurance_tweets.json')

# %%
df['clean_text'] = df['full_text'].apply(lambda x: p.clean(x))

# %%
from string import punctuation

nlp = spacy.load('en_core_web_sm')
def get_hotwords(text):
    result = []
    pos_tag = ['PROPN', 'ADJ', 'NOUN'] # 1
    doc = nlp(text.lower()) # 2
    for token in doc:
        # 3
        if(token.text in nlp.Defaults.stop_words or token.text in punctuation):
            continue
        # 4
        if(token.pos_ in pos_tag):
            result.append(token.text)
                
    return result # 5

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

sentiment_model = SentimentIntensityAnalyzer()

df['sentiment'] = df['clean_text'].apply(lambda x: sentiment_model.polarity_scores(x)['compound'])

# %%
df['objectivity'] = df['clean_text'].apply(lambda x: sentiment_model.polarity_scores(x)['neu'])
df['subjectivity'] = df['clean_text'].apply(lambda x: sentiment_model.polarity_scores(x)['pos'])
df['number_of_mentioned_entities'] = df['entities'].apply(lambda x: len(x['user_mentions']))
df['keywords'] = df['clean_text'].apply(lambda x: get_hotwords(x))
df['num_keywords'] = df['keywords'].apply(lambda x: len(x))
df['num_noun_chunks'] = df['clean_text'].apply(lambda x: len(list(nlp(x).noun_chunks)))

# %%
df
# Out:
#                    created_at                   id               id_str  \
# 0   2022-09-11 04:57:05+00:00  1568825936711122945  1568825936711122944
# 1   2022-09-11 04:57:03+00:00  1568825928498974720  1568825928498974720
# 2   2022-09-11 04:57:03+00:00  1568825928192782338  1568825928192782336
# 3   2022-09-11 04:57:01+00:00  1568825922358284290  1568825922358284288
# 4   2022-09-11 04:56:57+00:00  1568825901865136128  1568825901865136128
# ..                        ...                  ...                  ...
# 995 2022-09-11 04:18:55+00:00  1568816331734269952  1568816331734269952
# 996 2022-09-11 04:18:55+00:00  1568816331042205702  1568816331042205696
# 997 2022-09-11 04:18:54+00:00  1568816326713479170  1568816326713479168
# 998 2022-09-11 04:18:53+00:00  1568816325325111296  1568816325325111296
# 999 2022-09-11 04:18:53+00:00  1568816323366469632  1568816323366469632
#
#                                              full_text  truncated  \
# 0    @TeddiThompsonS1 @YouTube @karen_dippity they ...      False
# 1    RT @blair_fix: Important thread here. US healt...      False
# 2    RT @depechejoe: Hey, if you’re like me and cur...      False
# 3    Also insurance companies won’t credential ther...      False
# 4    RT @David_Slotnick: Just got my son’s hospital...      False
# ..                                                 ...        ...
# 995  @dennistlin Are there still insurance policies...      False
# 996  RT @David_Slotnick: Just got my son’s hospital...      False
# 997  RT @David_Slotnick: Just got my son’s hospital...      False
# 998  RT @David_Slotnick: Just got my son’s hospital...      False
# 999  @David_Slotnick The amount of hours that get s...      False
#
#     display_text_range                                           entities  \
# 0            [41, 184]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1             [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2             [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3              [0, 95]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4             [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# ..                 ...                                                ...
# 995          [12, 133]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 996           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 997           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 998           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 999          [16, 251]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                               metadata  \
# 0    {'iso_language_code': 'en', 'result_type': 're...
# 1    {'iso_language_code': 'en', 'result_type': 're...
# 2    {'iso_language_code': 'en', 'result_type': 're...
# 3    {'iso_language_code': 'en', 'result_type': 're...
# 4    {'iso_language_code': 'en', 'result_type': 're...
# ..                                                 ...
# 995  {'iso_language_code': 'en', 'result_type': 're...
# 996  {'iso_language_code': 'en', 'result_type': 're...
# 997  {'iso_language_code': 'en', 'result_type': 're...
# 998  {'iso_language_code': 'en', 'result_type': 're...
# 999  {'iso_language_code': 'en', 'result_type': 're...
#
#                                                 source  in_reply_to_status_id  \
# 0    <a href="https://mobile.twitter.com" rel="nofo...           1.568825e+18
# 1    <a href="http://twitter.com/download/android" ...                    NaN
# 2    <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 3    <a href="http://twitter.com/download/iphone" r...                    NaN
# 4    <a href="http://twitter.com/download/iphone" r...                    NaN
# ..                                                 ...                    ...
# 995  <a href="http://twitter.com/download/android" ...           1.568731e+18
# 996  <a href="http://twitter.com/download/iphone" r...                    NaN
# 997  <a href="http://twitter.com/download/iphone" r...                    NaN
# 998  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 999  <a href="http://twitter.com/download/iphone" r...           1.568602e+18
#
#      ...  possibly_sensitive  quoted_status  \
# 0    ...                 NaN            NaN
# 1    ...                 NaN            NaN
# 2    ...                 NaN            NaN
# 3    ...                 NaN            NaN
# 4    ...                 NaN            NaN
# ..   ...                 ...            ...
# 995  ...                 NaN            NaN
# 996  ...                 NaN            NaN
# 997  ...                 NaN            NaN
# 998  ...                 NaN            NaN
# 999  ...                 NaN            NaN
#
#                                             clean_text sentiment objectivity  \
# 0    they have to have insurance, right...lolol..is...    0.0000       1.000
# 1    : Important thread here. US health insurance c...    0.5023       0.710
# 2    : Hey, if youre like me and currently without ...    0.6901       0.802
# 3    Also insurance companies wont credential thera...    0.0000       1.000
# 4    : Just got my sons hospital and NICU bill. It ...    0.7177       0.778
# ..                                                 ...       ...         ...
# 995  Are there still insurance policies for cases s...   -0.3182       0.700
# 996  : Just got my sons hospital and NICU bill. It ...    0.7177       0.778
# 997  : Just got my sons hospital and NICU bill. It ...    0.7177       0.778
# 998  : Just got my sons hospital and NICU bill. It ...    0.7177       0.778
# 999  The amount of hours that get spent in my workp...   -0.1027       0.884
#
#     subjectivity number_of_mentioned_entities  \
# 0          0.000                            3
# 1          0.213                            1
# 2          0.198                            1
# 3          0.000                            0
# 4          0.222                            1
# ..           ...                          ...
# 995        0.105                            1
# 996        0.222                            1
# 997        0.222                            1
# 998        0.222                            1
# 999        0.053                            1
#
#                                               keywords  num_keywords  \
# 0    [insurance, right, lolol, dark, corner, muthaf...             8
# 1    [important, thread, health, insurance, compani...             9
# 2    [insurance, income, good, time, new, covid, bo...             8
# 3              [insurance, companies, therapist, area]             4
# 4        [sons, hospital, nicu, bill, good, insurance]             6
# ..                                                 ...           ...
# 995  [insurance, policies, cases, teams, losses, co...             7
# 996      [sons, hospital, nicu, bill, good, insurance]             6
# 997      [sons, hospital, nicu, bill, good, insurance]             6
# 998      [sons, hospital, nicu, bill, good, insurance]             6
# 999  [hours, workplace, treatments, insurance, orde...            11
#
#      num_noun_chunks
# 0                  8
# 1                  5
# 2                  7
# 3                  2
# 4                  8
# ..               ...
# 995                7
# 996                8
# 997                8
# 998                8
# 999               11
#
# [1000 rows x 39 columns]

# %%
# split df['user'] into multiple columns
df_user = pd.json_normalize(df['user'])

# %%
# merge df_user columns with df
df = pd.concat([df, df_user], axis=1)

# %% [markdown]
# ## Getting the age of a Twitter User
#
# To find the age of the user who comments about insurance, we have to use a multi-task model, that predicts the age from the user's profile photo.
#
# Extract Profile Photo -> Extract Face and Bounding Box -> Predict Age
#
# The Vision API only supports 100 requests a day. Therefore we will only take the most liked tweets. Since this is just an MVP, we reduce the number of rows to 100 temporarily.

# %%
# sort by favourite count
df = df.sort_values(by='favorite_count', ascending=False)

# only keep top 100
df = df.head(100)

# %%
import requests

client_id = '7a6LuJEWWp2vLyZ1t7WXwiWg'
client_secret = '5a89SdXjQPflywdhOzbNJJBiM3O9cvSavj4Cs1Ya9lSsFqZS'

def get_age(url):
    params = {'url': url}
    quality = requests.get('https://api.everypixel.com/v1/faces', params=params, auth=(client_id, client_secret)).json()
    
    return quality

# %%
get_age("https://media-exp1.licdn.com/dms/image/C4D03AQGkhJb4Y2re9A/profile-displayphoto-shrink_200_200/0/1656782604967?e=2147483647&v=beta&t=QwuM1Z1RezaixDrV4IIL00AvUZr8IcfLFb9pQWA4ifU")
# Out:
# {'faces': [{'bbox': [70.79667948843725,
#     45.70013444457381,
#     130.9501486036786,
#     123.66000083422752],
#    'score': 0.9998667240142822,
#    'age': 21.74080175369454,
#    'class': 'Age - Young Adult'}],
#  'status': 'ok'}

# %%
df['profile_image'] = df['profile_image_url'].apply(lambda x: x.replace('_normal', ''))

# %%
df['age'] = df['profile_image'].apply(lambda x: get_age(x))

# %%
df.to_csv('insurance_tweets_100.csv', index=False)

# %%
for i in df['age']:
    print(i)
# Out:
# {'faces': [{'bbox': [171.0671086653303, 40.37527102334695, 222.46599717375284, 118.78920079642005], 'score': 0.9996312856674194, 'age': 35.608995144531946, 'class': 'Age - Adult'}], 'status': 'ok'}
# {'faces': [{'bbox': [148.98461672952354, 79.22403584919972, 234.9660673854952, 212.92229996267056], 'score': 0.9999896287918091, 'age': 32.367901904755854, 'class': 'Age - Adult'}], 'status': 'ok'}
# {'faces': [], 'status': 'ok'}
# {'faces': [{'bbox': [110.51525882032874, 31.554608191784844, 147.00150835306914, 77.49420380723092], 'score': 0.9993622899055481, 'age': 25.65454548449634, 'class': 'Age - Young Adult'}], 'status': 'ok'}
# {'faces': [{'bbox': [107.97126313221352, 70.0158066086653, 220.22753354701797, 231.8404070699029], 'score': 0.9998995065689087, 'age': 23.37673780604382, 'class': 'Age - Young Adult'}], 'status': 'ok'}
# {'faces': [{'bbox': [133.87787635932975, 109.42740428675958, 193.07209406038587, 201.68689977513426], 'score': 0.9983048439025879, 'age': 30.569304449672927, 'class': 'Age - Adult'}], 'status': 'ok'}
# {'faces': [], 'status': 'ok'}
# {'faces': [{'bbox': [157.8761448660187, 52.30156506612894, 222.64527799141428, 138.65935736469953], 'score': 0.9997376799583435, 'age': 30.160303733449837, 'class': 'Age - Adult'}], 'status': 'ok'}
# {'faces': [{'bbox': [97.65253965221726, 112.51726104447091, 274.58698174536823, 352.4673689488843], 'score': 0.9999994039535522, 'age': 30.62408223910461, 'class': 'Age - Adult'}], 'status': 'ok'}
# {'faces': [{'bbox': [133.42237808946624, 103.43478989490248, 276.537122405672, 301.9679221377243], 'score': 0.9997311234474182, 'age': 19.71455893437087, 'class': 'Age - Young Adult'}], 'status': 'ok'}
# {'faces': [], 'status': 'ok'}
# {'faces': [{'bbox': [123.53563353079677, 112.7144259110817, 289.32647091509796, 348.6057067872039], 'score': 0.9999727010726929, 'age': 55.88772994262399, 'class': 'Age - Senior Adult'}], 'status': 'ok'}
# {'faces': [{'bbox': [78.6047312775956, 71.04295126586965, 300.9542038654252, 377.3069184302661], 'score': 0.9999998807907104, 'age': 26.778829882343416, 'class': 'Age - Young Adult'}], 'status': 'ok'}
# {'faces': [{'bbox':
 'class': 'Age - Young Adult'}], 'status': 'ok'}
# {'faces': [{'bbox': [155.6466349142165, 51.097546549161954, 184.6221862449177, 89.75145814518315], 'score': 0.9990715980529785}], 'status': 'ok'}
# {'faces': [], 'status': 'ok'}
# {'faces': [{'bbox': [126.44657885503473, 71.28212271354441, 264.5562217529401, 242.49432919419246], 'score': 0.9769430160522461, 'age': 33.49608318996616, 'class': 'Age - Adult'}], 'status': 'ok'}
# {'faces': [], 'status': 'ok'}
# {'faces': [{'bbox': [99.51087327184715, 6.138988113856736, 271.6077914801258, 163.95512705081745], 'score': 0.9998699426651001, 'age': 37.85124095233914, 'class': 'Age - Adult'}], 'status': 'ok'}
# {'faces': [{'bbox': [284.55878337367216, 32.74904602955644, 684.4104836258297, 442.1773035303774], 'score': 0.9466270208358765, 'age': 22.594627888611285, 'class': 'Age - Young Adult'}], 'status': 'ok'}
# {'faces': [], 'status': 'ok'}
# {'faces': [], 'status': 'ok'}
# {'faces': [{'bbox': [268.5976428341405, 102.9924773952891, 328.9985472148631, 175.51738217316037], 'score': 0.9996800422668457, 'age': 23.155448540506768, 'class': 'Age - Young Adult'}], 'status': 'ok'}
# {'faces': [{'bbox': [174.30667555352582, 91.55722192601174, 361.45035198016495, 357.6278015730389], 'score': 0.9999998807907104, 'age': 27.360999800497666, 'class': 'Age - Young Adult'}], 'status': 'ok'}
# {'faces': [], 'status': 'ok'}
# {'faces': [{'bbox': [95.76753025516796, 99.7520704292012, 352.6823458397688, 419.89211044060426], 'score': 1.0, 'age': 34.49330904587987, 'class': 'Age - Adult'}], 'status': 'ok'}
# {'faces': [{'bbox': [62.05923603137745, 142.00171440349274, 146.1230467273288, 252.86590279065385], 'score': 0.9996742010116577, 'age': 23.903124772477895, 'class': 'Age - Young Adult'}], 'status': 'ok'}
# {'faces': [{'bbox': [438.2858147137286, 4.458670635642692, 525.5754964466064, 114.05513555879115], 'score': 0.9989153146743774, 'age': 28.4170802726876, 'class': 'Age - Young Adult'}], 'status': 'ok'}
# {'faces': [{'bbox': [124.3693740924303, 75.09051073602996, 257.6036292524919, 250.29261889758217], 'score': 0.9999693632125854, 'age': 18.582591669161047, 'class': 'Age - Teenager'}], 'status': 'ok'}
# {'faces': [{'bbox': [114.03908171027868, 51.37046442371969, 195.9858695366592, 176.79639085629756], 'score': 0.9997475743293762, 'age': 25.398670965078054, 'class': 'Age - Young Adult'}], 'status': 'ok'}
# {'faces': [{'bbox': [473.5738121760612, 29.98744527726181, 621.3667642707487, 179.503786884151], 'score': 0.9995562434196472, 'age': 26.899166235816665, 'class': 'Age - Young Adult'}], 'status': 'ok'}
# {'faces': [{'bbox': [116.712786159884, 58.76200139855173, 268.8439158189528, 272.80555937097307], 'score': 0.9981787204742432, 'age': 25.56030747316254, 'class': 'Age - Young Adult'}], 'status': 'ok'}
# {'faces': [{'bbox': [105.46734171634198, 92.62719937310534, 257.3475863059593, 273.8506596473601], 'score': 0.9996849298477173, 'age': 18.49900069987052, 'class': 'Age - Teenager'}], 'status': 'ok'}
# {'faces': [{'bbox': [173.30695432903352, 97.98707552345238, 198.01949847719382, 131.25422898713035], 'score': 0.997329831123352}], 'status': 'ok'}
# {'faces': [{'bbox': [543.0963320570459, 47.86525108102527, 656.4149592248477, 189.4728681431686], 'score': 0.9997978806495667, 'age': 25.105736582481768, 'class': 'Age - Young Adult'}], 'status': 'ok'}
# {'faces': [], 'status': 'ok'}
# {'faces': [{'bbox': [115.91094676305039, 49.09249493209434, 206.50465428917602, 168.7070833892964], 'score': 0.9999068975448608, 'age': 31.967518615310837, 'class': 'Age - Adult'}], 'status': 'ok'}
# {'faces': [{'bbox': [104.51618403811665, 87.26486225167277, 145.52816302713367, 136.3614913940062], 'score': 0.9979583024978638, 'age': 27.58670122836338, 'class': 'Age - Young Adult'}], 'status': 'ok'}
# {'faces': [], 'status': 'ok'}
# {'faces': [{'bbox': [127.43568913974762, 95.44605556474905, 315.59405146431305, 354.60280131432137], 'score': 0.9997269511222839, 'age': 25.96740434018284, 'class': 'Age - Young Adult'}], 'status': 'ok'}
# {'faces': [{'bbox': [105.66319506782905, 94.61169892124944, 245.77826896363263, 288.6618381793275], 'score': 0.9998121857643127, 'age': 20.83564058398042, 'class': 'Age - Young Adult'}], 'status': 'ok'}
# {'faces': [{'bbox': [120.735297464777, 144.249037564996, 287.6806834226641, 347.5497319194411], 'score': 0.9972129464149475, 'age': 27.202222000574693, 'class': 'Age - Young Adult'}], 'status': 'ok'}
# {'status': 'error', 'message': 'ratelimit exceeded 100 requests per 86400 seconds'}

# %%
df['age_num'] = df['age'].apply(lambda x: x['faces'][0]['age'] if ('faces' in x) and (len(x['faces']) > 0) and ('age' in x['faces'][0]) else 18)
df['age_group'] = df['age'].apply(lambda x: x['faces'][0]['class'] if ('faces' in x) and (len(x['faces']) > 0) and ('age' in x['faces'][0]) else 18)

# %%
# K means clustering
from sklearn.cluster import KMeans

km = KMeans(n_clusters=3, random_state=0)
km.fit(df[['age_num', 'sentiment', 'num_noun_chunks', 'num_keywords', 'number_of_mentioned_entities']])
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
# plot clusters
import matplotlib.pyplot as plt

plt.scatter(df['age_num'], df['subjectivity'], c=km.labels_, cmap='rainbow')
plt.xlabel('Age')
plt.ylabel('Subjectivity')
# Out:
# Text(0, 0.5, 'Subjectivity')

# %%
attributes = df[['age_num', 'sentiment', 'num_noun_chunks', 'num_keywords', 'number_of_mentioned_entities']]
attributes
# Out:
#        age_num  sentiment  num_noun_chunks  num_keywords  \
# 949  35.608995    -0.4738               13             9
# 934  32.367902    -0.4257               11             9
# 831  18.000000    -0.8225                7             6
# 706  25.654545    -0.3167               10            11
# 937  23.376738     0.4927               19            26
# ..         ...        ...              ...           ...
# 675  18.000000     0.7177                8             6
# 724  25.967404     0.6114                5            13
# 711  20.835641     0.6901                7             8
# 712  27.202222    -0.4939                6             6
# 713  18.000000     0.7177                8             6
#
#      number_of_mentioned_entities
# 949                             0
# 934                             0
# 831                             1
# 706                             0
# 937                             0
# ..                            ...
# 675                             1
# 724                             1
# 711                             1
# 712                             2
# 713                             1
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Exploration

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np

X = np.array(attributes)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA()
pca.fit(X_scaled)
# Out:
# PCA()

# %%
len(pca.components_)
# Out:
# 5

# %%
print('Explained Variance Ratio = ', sum(pca.explained_variance_ratio_[: 2]))
# Out:
# Explained Variance Ratio =  0.5865707511500571

# %%
import plotly.graph_objs as pgo

data3 = pgo.Data([
    pgo.Bar(
            y=pca.explained_variance_ratio_,
    )
])
# Out:
# /Users/SidharrthNagappan/.virtualenvs/multitask-bert/lib/python3.8/site-packages/plotly/graph_objs/_deprecations.py:31: DeprecationWarning: plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.
#
#   warnings.warn(

# %%
# plot data3
import plotly.graph_objects as go

go.Figure(data=data3).show()

# %% [markdown]
# Only take the first two principal components.

# %%
pca.n_components = 2
X_reduced = pca.fit_transform(X_scaled)
df_X_reduced = pd.DataFrame(X_reduced, index=df.index)

# %%
trace = pgo.Scatter(x=df_X_reduced[0],
                    y=df_X_reduced[1],
                    text=df.index,
                    mode='markers',
                    # Size by total population of each neighborhood. 
                    marker=pgo.Marker(size=attributes['num_keywords'],
                                      sizemode='diameter',
                                      sizeref=attributes['num_keywords'].max()/50,
                                      opacity=0.5)
)

data5 = pgo.Data([trace])

# %%
layout5 = pgo.Layout(title='Insurance Tweets',
                     xaxis=pgo.XAxis(showgrid=True,
                                     zeroline=False,
                                     showticklabels=False),
                     yaxis=pgo.YAxis(showgrid=True,
                                     zeroline=False,
                                     showticklabels=False),
                     hovermode='closest'
)
# Out:
# /Users/SidharrthNagappan/.virtualenvs/multitask-bert/lib/python3.8/site-packages/plotly/graph_objs/_deprecations.py:544: DeprecationWarning:
#
# plotly.graph_objs.XAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.XAxis
#   - plotly.graph_objs.layout.scene.XAxis
#
#
# /Users/SidharrthNagappan/.virtualenvs/multitask-bert/lib/python3.8/site-packages/plotly/graph_objs/_deprecations.py:572: DeprecationWarning:
#
# plotly.graph_objs.YAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.YAxis
#   - plotly.graph_objs.layout.scene.YAxis

# %%
fig5 = pgo.Figure(data=data5, layout=layout5)

go.Figure(data=fig5).show()

# %% [markdown]
# A larger number of people mention more insurance-related keywords in their tweets, while few keep their tweets brief.

# %%
# convert X_scaled to dataframe

X_scaled_df = pd.DataFrame(X_scaled, index=df.index)
X_scaled_df.columns = ["pca-one", "pca-two", "pca-three", "pca-four", "pca-five"]

# %%
import plotly.express as px

px.scatter_3d(X_scaled_df, x='pca-one', y='pca-two', z='pca-three', width=800)

# %% [markdown]
# The 3D graph may not be as informative as there is limited data.

# %%
df.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'full_text', 'truncated',
#        'display_text_range', 'entities', 'metadata', 'source',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'is_quote_status', 'retweet_count', 'favorite_count',
#        'favorited', 'retweeted', 'lang', 'retweeted_status',
#        'quoted_status_id', 'quoted_status_id_str', 'extended_entities',
#        'possibly_sensitive', 'quoted_status', 'clean_text', 'sentiment',
#        'objectivity', 'subjectivity', 'number_of_mentioned_entities',
#        'keywords', 'num_keywords', 'num_noun_chunks', 'id', 'id_str', 'name',
#        'screen_name', 'location', 'description', 'url', 'protected',
#        'followers_count', 'friends_count', 'listed_count', 'created_at',
#        'favourites_count', 'utc_offset', 'time_zone', 'geo_enabled',
#        'verified', 'statuses_count', 'lang', 'contributors_enabled',
#        'is_translator', 'is_translation_enabled', 'profile_background_color',
#        'profile_background_image_url', 'profile_background_image_url_https',
#        'profile_background_tile', 'profile_image_url',
#        'profile_image_url_https', 'profile_banner_url', 'profile_link_color',
#        'profile_sidebar_border_color', 'profile_sidebar_fill_color',
#        'profile_text_color', 'profile_use_background_image',
#        'has_extended_profile', 'default_profile', 'default_profile_image',
#        'following', 'follow_request_sent', 'notifications', 'translator_type',
#        'withheld_in_countries', 'entities.description.urls',
#        'entities.url.urls', 'age', 'profile_image', 'age_num', 'age_group'],
#       dtype='object')

# %% [markdown]
# ## Findings

# %%
from textblob import TextBlob
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from nltk.corpus import stopwords

stops = stopwords.words('english')

def black_color_func(word, font_size, position,orientation,random_state=None, **kwargs):
    return("hsl(0,100%, 1%)")

# for each age group, get the most common keywords
for i in df['age_group'].unique():
    print(i)
    # plot word cloud
    cloud = WordCloud(font_path = '/Library/Fonts/Arial Unicode.ttf', background_color="white", width=2000, height=1000, max_words=500, stopwords=stops + ['insurance']).generate(" ".join(df[df['age_group'] == i]['clean_text']))
    cloud.recolor(color_func=black_color_func)
    plt.figure(figsize=(10, 15))
    plt.imshow(cloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()
# Out:
# Age - Adult
# 18
# Age - Young Adult
# Age - Senior Adult
# Age - Kid
# Age - Toddler
# Age - Mature Adult
# Age - Teenager

# %% [markdown]
# From common aspects mentioned, most commenters are adults, who talk about general terms like hospitalisation. Senior citizens mainly refer to cancer and illneses related to old age. It may be recommended to promote certain insurance plans to senior citizens who mention issues about medical bills in their tweets.

# %% [markdown]
# ### Perception of insurance by age group

# %%
# average sentiment by age group
sent_by_age = pd.DataFrame(df.groupby('age_group')['sentiment'].mean())
sent_by_age
# Out:
#                     sentiment
# age_group
# 18                   0.232466
# Age - Adult         -0.032131
# Age - Kid           -0.152500
# Age - Mature Adult   0.168875
# Age - Senior Adult  -0.710500
# Age - Teenager       0.470250
# Age - Toddler       -0.549900
# Age - Young Adult    0.091294

# %%
px.bar(sent_by_age, x=sent_by_age.index, y='sentiment', width=600)

# %% [markdown]
# Older people generally have worse comments about insurance plans.
